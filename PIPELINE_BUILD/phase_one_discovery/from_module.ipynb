# %%
import pandas as pd
import numpy as np

# %%
import tqdm
import time
import tweepy
import config

# %%
from data_handler import HurricaneDataHandler as DH

# %%
short_list = [ 910783391829598208,
 913032371435433984,
 914175720968028161,
 910549451214872577,
 914176943033024514,
 913879154789056512,
 914524833047810048,
 912385296557334530,
 912218742930550784,
 912123826217025536]

# %%
HC = DH()
# Out:
# 27600
# name 'Error' is not defined

# %%
# %%time
# df = HC.augment_training_text()

# %%
twts = HC.training_tweet_index
type(twts)
# Out:
# pandas.core.series.Series

# %%
# HC.retrieve_tweets(short_list)

# %%
# df = HC.collect_tweet_dfs(list(twts), 0)

# %%
# df.shape

# %%
len(twts)
# Out:
# 27443

# %%
df = HC.augment_training_text()
df.shape
# Out:
# Rate limit exceeded. Sleeping for 79 seconds.
# 1700
# name 'Error' is not defined
# (1032, 17)

# %%
HC.labeled_with_features
# Out:
#                  tweet_id                                               text  \
# 0      910783670134476800  "Hurricane Maria Live Updates: Catastrophic Fl...
# 1      912134938727780355  Getting food to the island is, obviously, crit...
# 2      910669838842056704  My heart breaks for the families in Puerto Ric...
# 3      912287091026997248  RT @dreynders: #B-FAST sending medical, recons...
# 4      914175720968028161  @alan5422 @nytimes U.S. boots have been on the...
# ...                   ...                                                ...
# 18659  783391937004838921  That's scary!!! 🙏🏻 praying for everyone's safe...
# 18660  783870371887853568  RT @AlishaLaventure: The damage in #Haiti is h...
# 18661  783699222402957317  REPORTS: Hurricane Matthew kills at least 10 w...
# 18662  783399699994648576  Hurricane-hit southern Haiti cut off after bri...
# 18663  783885207514394624  Retweeted Al Jazeera News (@AJENews):\n\nSome ...
#
#         author_id                created_at     conversation_id  \
# 0       627954585 2017-09-21 08:32:03+00:00  910783670134476800
# 1       543450752 2017-09-25 02:01:30+00:00  912134938727780355
# 2      3181770608 2017-09-21 00:59:43+00:00  910669838842056704
# 3      3730165402 2017-09-25 12:06:06+00:00  912287091026997248
# 4       241033134 2017-09-30 17:10:51+00:00  914109786341429248
# ...           ...                       ...                 ...
# 18659    45278113 2016-10-04 19:42:47+00:00  783391937004838921
# 18660   338774541 2016-10-06 03:23:54+00:00  783870371887853568
# 18661   345161879 2016-10-05 16:03:49+00:00  783699222402957317
# 18662   119807651 2016-10-04 20:13:37+00:00  783399699994648576
# 18663   252147867 2016-10-06 04:22:52+00:00  783885207514394624
#
#                                                 entities  \
# 0      {'annotations': [{'start': 1, 'end': 15, 'prob...
# 1      {'urls': [{'start': 52, 'end': 75, 'url': 'htt...
# 2      {'annotations': [{'start': 36, 'end': 46, 'pro...
# 3      {'mentions': [{'start': 3, 'end': 13, 'usernam...
# 4      {'mentions': [{'start': 0, 'end': 9, 'username...
# ...                                                  ...
# 18659  {'annotations': [{'start': 100, 'end': 104, 'p...
# 18660  {'annotations': [{'start': 36, 'end': 40, 'pro...
# 18661  {'annotations': [{'start': 9, 'end': 25, 'prob...
# 18662  {'annotations': [{'start': 23, 'end': 27, 'pro...
# 18663  {'annotations': [{'start': 10, 'end': 24, 'pro...
#
#                                      context_annotations  \
# 0      [{'domain': {'id': '13', 'name': 'Place', 'des...
# 1                                               no_value
# 2      [{'domain': {'id': '13', 'name': 'Place', 'des...
# 3      [{'domain': {'id': '29', 'name': 'Events [Enti...
# 4      [{'domain': {'id': '47', 'name': 'Brand', 'des...
# ...                                                  ...
# 18659                                           no_value
# 18660                                           no_value
# 18661                                           no_value
# 18662                                           no_value
# 18663                                           no_value
#
#       edit_history_tweet_ids in_reply_to_user_id  \
# 0       [910783670134476800]            no_value
# 1       [912134938727780355]            no_value
# 2       [910669838842056704]            no_value
# 3       [912287091026997248]            no_value
# 4       [914175720968028161]           588769770
# ...                      ...                 ...
# 18659   [783391937004838921]            no_value
# 18660   [783870371887853568]            no_value
# 18661   [783699222402957317]            no_value
# 18662   [783399699994648576]            no_value
# 18663   [783885207514394624]            no_value
#
#                                     attachments lang possibly_sensitive  \
# 0                                      no_value   en           no_value
# 1                                      no_value   en           no_value
# 2                                      no_value   en           no_value
# 3                                      no_value   en           no_value
# 4      {'media_keys': ['3_914175714278105088']}   en           no_value
# ...                                         ...  ...                ...
# 18659                                  no_value   en           no_value
# 18660                                  no_value   en           no_value
# 18661  {'media_keys': ['3_783699218670071809']}   en           no_value
# 18662                                  no_value   en           no_value
# 18663                                  no_value   en           no_value
#
#                                           public_metrics  \
# 0      {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1      {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 2      {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 3      {'retweet_count': 15, 'reply_count': 0, 'like_...
# 4      {'retweet_count': 0, 'reply_count': 1, 'like_c...
# ...                                                  ...
# 18659  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 18660  {'retweet_count': 9, 'reply_count': 0, 'like_c...
# 18661  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 18662  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 18663  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#               referenced_tweets reply_settings    source  \
# 0                      no_value       everyone  no_value
# 1                  [(type, id)]       everyone  no_value
# 2                      no_value       everyone  no_value
# 3                  [(type, id)]       everyone  no_value
# 4      [(type, id), (type, id)]       everyone  no_value
# ...                         ...            ...       ...
# 18659              [(type, id)]       everyone  no_value
# 18660              [(type, id)]       everyone  no_value
# 18661                  no_value       everyone  no_value
# 18662                  no_value       everyone  no_value
# 18663                  no_value       everyone  no_value
#
#                                   class_label
# 0                          caution_and_advice
# 1      rescue_volunteering_or_donation_effort
# 2                        sympathy_and_support
# 3      rescue_volunteering_or_donation_effort
# 4      rescue_volunteering_or_donation_effort
# ...                                       ...
# 18659                    sympathy_and_support
# 18660       infrastructure_and_utility_damage
# 18661                  injured_or_dead_people
# 18662              other_relevant_information
# 18663       infrastructure_and_utility_damage
#
# [18664 rows x 17 columns]
